# %%
import subprocess, msprime, tskit, os, statistics, pyslim
import numpy as np
import pandas as pd
import random
# import matplotlib.pyplot as plt
# import scipy.stats as stats
# import pylab
import math
# import rpy2
# import rpy2.robjects as robjects
# from rpy2.robjects.packages import importr

# energy = importr("energy")

# %%
Nrun = 100 # number of SIS runs
Ne = 6200 
Stop = 11 # the stopping criteria
SeqLen = 5.0e06 # sequence length
MutRate = 1e-9 # mutation rate
RecRate = 0 # recombination rate
Tau = 50
SampleSize = 20

# %%
# For writing input files
def WriteInput(ts, Nrun, SampleSize, Ne, Stop, SeqLen, MutRate, RecRate, filename):
    filename_tmp = filename + "1"
    f1 = open(filename_tmp,"w+")
    f1.write("Number of runs = %d\n" % Nrun)
    f1.write("Effective population size = %d\n" % Ne)
    f1.write("Recombination = %.15f\n" % RecRate)
    f1.write("Mutation = %.15f\n" % MutRate)
    f1.write("Length = %f\n" % SeqLen)
    f1.write("Stop = %d\n" % Stop)
    f1.write("#")
    f1.close()
    
    filename_tmp = filename + "2"
    f2 = open(filename_tmp,"w+")
    
    # Get distinct haplotypes
    geno =  ts.genotype_matrix() 
    L = len(geno)
    f2.write("Loci = %d\n" % (L+1))
    SampleSize = ts.get_sample_size()
    f2.write("Genes = %d\n" % SampleSize)
          
    # initialise with the first distinct haplotype
    haps_1 = [0]
    haps_2 = [geno[i][0] for i in range(L)]
    haps = np.hstack((haps_1, haps_2))
    # the number of this haplotype is 1
    #haps.append(1)
    haps = np.hstack((haps, [1]))
    haps = np.array([haps])
    ntype = 1
    order = [0]

    for j in range(1,SampleSize):
        new_1 = [0]
        new_2 = [geno[i][j] for i in range(L)]
        new = np.hstack((new_1, new_2))
        flag = 0 # flag=0: a new distinct haplotype
        for k in range(ntype):
            if(haps[k][:(L+1)].tolist() == new.tolist()):
                haps[k][(L+1)] += 1
                flag = 1
                order.append(j)
                break
        if flag == 0:
            order.append(ntype)
            ntype += 1
            #new.append(1)
            new = np.hstack((new, [1]))
            haps = np.vstack([haps, new]) 
          
    f2.write("Distinct Haplotypes = %d\n" % ntype)
    tot=0
    for i in range(ntype):
        tot = tot+ np.sum(haps[i,:(L+1)])*haps[i,(L+1)]
    stationary = tot/(L*SampleSize)
    #stationary = np.sum(haps)/(L*SampleSize)
    f2.write("Stationary = %.5f\n" % (1-stationary))
    print("stationary = %.5f\n" % (1-stationary))  
    
    f2.write("Haplotypes\n")
    for i in range(haps.shape[0]):
        for j in range(haps.shape[1]):
            if j == L+1:
                f2.write("%d\n" % haps[i][j])
            else:
                f2.write("%d " % haps[i][j])
    
    # Mutation transition rates
    f2.write("\nMutation\n0.0 1.0 0.0 1.0\n")
             
    # Genetic positions
    f2.write("\nPositions\n")
    positions = [0.0]
    for s in ts.sites():
        positions.append(s.position)
    for i in range(len(positions)):
        f2.write("%.2f " %(positions[i]))
             
    f2.write("\n#")
    f2.close()
    order = sorted(range(len(order)), key=lambda k: order[k])
    return order;

# %%
tree = pyslim.load("recipe_50gb.trees")

# %%
tot = 0
for c in range(Ne*2):
    clade1 = c
    count = 0
    ts = tree.at(100)
    for s in range(Ne*2, Ne*4):
        if ts.is_descendant(s, clade1):
            count = count + 1
    if count>0:
        tot = tot + count
        print("clade %d contribute to %d samples" %(c, count))
# Out:
# clade 39 contribute to 3 samples
# clade 137 contribute to 52 samples
# clade 153 contribute to 14 samples
# clade 192 contribute to 1 samples
# clade 235 contribute to 35 samples
# clade 258 contribute to 12 samples
# clade 278 contribute to 8 samples
# clade 287 contribute to 1 samples
# clade 296 contribute to 7 samples
# clade 447 contribute to 19 samples
# clade 487 contribute to 54 samples
# clade 513 contribute to 16 samples
# clade 521 contribute to 20 samples
# clade 589 contribute to 103 samples
# clade 612 contribute to 22 samples
# clade 618 contribute to 31 samples
# clade 642 contribute to 25 samples
# clade 666 contribute to 57 samples
# clade 688 contribute to 28 samples
# clade 692 contribute to 34 samples
# clade 738 contribute to 12 samples
# clade 757 contribute to 9 samples
# clade 765 contribute to 3 samples
# clade 788 contribute to 8 samples
# clade 847 contribute to 12 samples
# clade 855 contribute to 30 samples
# clade 990 contribute to 22 samples
# clade 992 contribute to 24 samples
# clade 1009 contribute to 34 samples
# clade 1016 contribute to 33 samples
# clade 1048 contribute to 3 samples
# clade 1049 contribute to 20 samples
# clade 1055 contribute to 31 samples
# clade 1068 contribute to 7 samples
# clade 1073 contribute to 45 samples
# clade 1170 contribute to 6 samples
# clade 1185 contribute to 55 samples
# clade 1215 contribute to 32 samples
# clade 1260 contribute to 24 samples
# clade 1268 contribute to 16 samples
# clade 1272 contribute to 10 samples
# clade 1294 contribute to 11 samples
# clade 1342 contribute to 4 samples
# clade 1429 contribute to 22 samples
# clade 1436 contribute to 11 samples
# clade 1449 contribute to 25 samples
# clade 1543 contribute to 23 samples
# clade 1600 contribute to 9 samples
# clade 1610 contribute to 71 samples
# clade 1630 contribute to 6 samples
# clade 1634 contribute to 15 samples
# clade 1672 contribute to 56 samples
# clade 1699 contribute to 67 samples
# clade 1711 contribute to 86 samples
# clade 1713 contribute to 38 samples
# clade 1768 contribute to 30 samples
# clade 1805 contribute to 21 samples
# clade 1866 contribute to 36 samples
# clade 1871 contribute to 11 samples
# clade 1872 contribute to 27 samples
# clade 1889 contribute to 16 samples
# clade 1948 contribute to 35 samples
# clade 1958 contribute to 43 samples
# clade 1997 contribute to 25 samples
# clade 2000 contribute to 50 samples
# clade 2008 contribute to 19 samples
# clade 2022 contribute to 23 samples
# clade 2043 contribute to 19 samples
# clade 2045 contribute to 57 samples
# clade 2059 contribute to 31 samples
# clade 2072 contribute to 2 samples
# clade 2100 contribute to 44 samples
# clade 2104 contribute to 4 samples
# clade 2127 contribute to 38 samples
# clade 2147 contribute to 64 samples
# clade 2161 contribute to 13 samples
# clade 2226 contribute to 18 samples
# clade 2238 contribute to 17 samples
# clade 2248 contribute to 57 samples
# clade 2341 contribute to 9 samples
# clade 2346 contribute to 14 samples
# clade 2347 contribute to 16 samples
# clade 2358 contribute to 17 samples
# clade 2385 contribute to 21 samples
# clade 2406 contribute to 24 samples
# clade 2498 contribute to 8 samples
# clade 2507 contribute to 4 samples
# clade 2521 contribute to 9 samples
# clade 2528 contribute to 12 samples
# clade 2542 contribute to 1 samples
# clade 2561 contribute to 7 samples
# clade 2594 contribute to 102 samples
# clade 2632 contribute to 52 samples
# clade 2667 contribute to 46 samples
# clade 2689 contribute to 21 samples
# clade 2705 contribute to 8 samples
# clade 2731 contribute to 7 samples
# clade 2771 contribute to 10 samples
# clade 2788 contribute to 34 samples
# clade 2812 contribute to 19 samples
# clade 2840 contribute to 9 samples
# clade 2870 contribute to 71 samples
# clade 2917 contribute to 14 samples
# clade 2927 contribute to 20 samples
# clade 2930 contribute to 19 samples
# clade 2992 contribute to 25 samples
# clade 3035 contribute to 28 samples
# clade 3099 contribute to 16 samples
# clade 3122 contribute to 6 samples
# clade 3161 contribute to 2 samples
# clade 3181 contribute to 20 samples
# clade 3203 contribute to 67 samples
# clade 3206 contribute to 56 samples
# clade 3226 contribute to 44 samples
# clade 3238 contribute to 4 samples
# clade 3266 contribute to 50 samples
# clade 3302 contribute to 38 samples
# clade 3318 contribute to 41 samples
# clade 3324 contribute to 54 samples
# clade 3329 contribute to 6 samples
# clade 3331 contribute to 49 samples
# clade 3387 contribute to 29 samples
# clade 3409 contribute to 16 samples
# clade 3413 contribute to 5 samples
# clade 3451 contribute to 38 samples
# clade 3479 contribute to 149 samples
# clade 3496 contribute to 5 samples
# clade 3524 contribute to 44 samples
# clade 3558 contribute to 1 samples
# clade 3569 contribute to 15 samples
# clade 3575 contribute to 42 samples
# clade 3601 contribute to 43 samples
# clade 3635 contribute to 10 samples
# clade 3639 contribute to 2 samples
# clade 3672 contribute to 39 samples
# clade 3675 contribute to 6 samples
# clade 3689 contribute to 9 samples
# clade 3702 contribute to 40 samples
# clade 3739 contribute to 5 samples
# clade 3760 contribute to 32 samples
# clade 3790 contribute to 57 samples
# clade 3801 contribute to 26 samples
# clade 3811 contribute to 13 samples
# clade 3822 contribute to 9 samples
# clade 3870 contribute to 14 samples
# clade 3909 contribute to 2 samples
# clade 3991 contribute to 62 samples
# clade 3996 contribute to 1 samples
# clade 4008 contribute to 59 samples
# clade 4057 contribute to 18 samples
# clade 4079 contribute to 34 samples
# clade 4248 contribute to 17 samples
# clade 4281 contribute to 24 samples
# clade 4287 contribute to 11 samples
# clade 4292 contribute to 9 samples
# clade 4299 contribute to 38 samples
# clade 4334 contribute to 73 samples
# clade 4342 contribute to 94 samples
# clade 4352 contribute to 18 samples
# clade 4412 contribute to 8 samples
# clade 4445 contribute to 9 samples
# clade 4466 contribute to 87 samples
# clade 4478 contribute to 15 samples
# clade 4483 contribute to 33 samples
# clade 4493 contribute to 1 samples
# clade 4508 contribute to 31 samples
# clade 4519 contribute to 13 samples
# clade 4525 contribute to 26 samples
# clade 4557 contribute to 22 samples
# clade 4566 contribute to 50 samples
# clade 4573 contribute to 19 samples
# clade 4589 contribute to 4 samples
# clade 4611 contribute to 28 samples
# clade 4612 contribute to 56 samples
# clade 4620 contribute to 92 samples
# clade 4680 contribute to 34 samples
# clade 4731 contribute to 20 samples
# clade 4792 contribute to 39 samples
# clade 4794 contribute to 4 samples
# clade 4814 contribute to 53 samples
# clade 4827 contribute to 49 samples
# clade 4867 contribute to 47 samples
# clade 4868 contribute to 10 samples
# clade 4902 contribute to 3 samples
# clade 4906 contribute to 13 samples
# clade 4918 contribute to 17 samples
# clade 4989 contribute to 73 samples
# clade 5044 contribute to 18 samples
# clade 5083 contribute to 34 samples
# clade 5094 contribute to 28 samples
# clade 5172 contribute to 5 samples
# clade 5206 contribute to 18 samples
# clade 5215 contribute to 38 samples
# clade 5236 contribute to 10 samples
# clade 5347 contribute to 10 samples
# clade 5370 contribute to 57 samples
# clade 5382 contribute to 14 samples
# clade 5383 contribute to 8 samples
# clade 5391 contribute to 8 samples
# clade 5399 contribute to 14 samples
# clade 5428 contribute to 80 samples
# clade 5533 contribute to 19 samples
# clade 5580 contribute to 3 samples
# clade 5588 contribute to 27 samples
# clade 5595 contribute to 71 samples
# clade 5626 contribute to 23 samples
# clade 5633 contribute to 18 samples
# clade 5655 contribute to 8 samples
# clade 5673 contribute to 27 samples
# clade 5707 contribute to 58 samples
# clade 5767 contribute to 7 samples
# clade 5776 contribute to 16 samples
# clade 5832 contribute to 11 samples
# clade 5874 contribute to 6 samples
# clade 5900 contribute to 55 samples
# clade 5914 contribute to 14 samples
# clade 6005 contribute to 4 samples
# clade 6006 contribute to 68 samples
# clade 6024 contribute to 18 samples
# clade 6034 contribute to 27 samples
# clade 6047 contribute to 13 samples
# clade 6051 contribute to 13 samples
# clade 6060 contribute to 12 samples
# clade 6073 contribute to 15 samples
# clade 6095 contribute to 5 samples
# clade 6138 contribute to 5 samples
# clade 6151 contribute to 17 samples
# clade 6193 contribute to 6 samples
# clade 6196 contribute to 3 samples
# clade 6211 contribute to 4 samples
# clade 6266 contribute to 18 samples
# clade 6269 contribute to 3 samples
# clade 6274 contribute to 59 samples
# clade 6277 contribute to 3 samples
# clade 6286 contribute to 7 samples
# clade 6350 contribute to 35 samples
# clade 6354 contribute to 16 samples
# clade 6367 contribute to 29 samples
# clade 6402 contribute to 3 samples
# clade 6409 contribute to 15 samples
# clade 6411 contribute to 2 samples
# clade 6428 contribute to 23 samples
# clade 6491 contribute to 23 samples
# clade 6507 contribute to 16 samples
# clade 6543 contribute to 17 samples
# clade 6554 contribute to 14 samples
# clade 6568 contribute to 6 samples
# clade 6594 contribute to 13 samples
# clade 6598 contribute to 10 samples
# clade 6614 contribute to 16 samples
# clade 6624 contribute to 28 samples
# clade 6642 contribute to 6 samples
# clade 6643 contribute to 17 samples
# clade 6649 contribute to 159 samples
# clade 6660 contribute to 6 samples
# clade 6681 contribute to 13 samples
# clade 6689 contribute to 38 samples
# clade 6698 contribute to 9 samples
# clade 6709 contribute to 17 samples
# clade 6716 contribute to 29 samples
# clade 6738 contribute to 4 samples
# clade 6743 contribute to 53 samples
# clade 6774 contribute to 22 samples
# clade 6816 contribute to 36 samples
# clade 6822 contribute to 11 samples
# clade 6830 contribute to 9 samples
# clade 6892 contribute to 15 samples
# clade 6905 contribute to 12 samples
# clade 6954 contribute to 4 samples
# clade 6959 contribute to 3 samples
# clade 6967 contribute to 6 samples
# clade 7000 contribute to 46 samples
# clade 7011 contribute to 53 samples
# clade 7020 contribute to 44 samples
# clade 7041 contribute to 36 samples
# clade 7048 contribute to 35 samples
# clade 7086 contribute to 61 samples
# clade 7093 contribute to 33 samples
# clade 7167 contribute to 4 samples
# clade 7180 contribute to 2 samples
# clade 7230 contribute to 9 samples
# clade 7269 contribute to 3 samples
# clade 7277 contribute to 59 samples
# clade 7295 contribute to 24 samples
# clade 7306 contribute to 18 samples
# clade 7330 contribute to 33 samples
# clade 7376 contribute to 28 samples
# clade 7436 contribute to 9 samples
# clade 7476 contribute to 25 samples
# clade 7484 contribute to 24 samples
# clade 7503 contribute to 14 samples
# clade 7520 contribute to 27 samples
# clade 7529 contribute to 83 samples
# clade 7530 contribute to 7 samples
# clade 7545 contribute to 22 samples
# clade 7558 contribute to 6 samples
# clade 7562 contribute to 15 samples
# clade 7563 contribute to 28 samples
# clade 7593 contribute to 14 samples
# clade 7610 contribute to 10 samples
# clade 7613 contribute to 22 samples
# clade 7633 contribute to 56 samples
# clade 7657 contribute to 29 samples
# clade 7669 contribute to 21 samples
# clade 7713 contribute to 6 samples
# clade 7744 contribute to 14 samples
# clade 7801 contribute to 30 samples
# clade 7970 contribute to 5 samples
# clade 7977 contribute to 30 samples
# clade 7990 contribute to 13 samples
# clade 8009 contribute to 14 samples
# clade 8028 contribute to 39 samples
# clade 8107 contribute to 26 samples
# clade 8109 contribute to 25 samples
# clade 8115 contribute to 23 samples
# clade 8116 contribute to 28 samples
# clade 8130 contribute to 19 samples
# clade 8134 contribute to 38 samples
# clade 8165 contribute to 54 samples
# clade 8182 contribute to 16 samples
# clade 8224 contribute to 3 samples
# clade 8232 contribute to 3 samples
# clade 8247 contribute to 46 samples
# clade 8249 contribute to 1 samples
# clade 8271 contribute to 2 samples
# clade 8291 contribute to 97 samples
# clade 8295 contribute to 7 samples
# clade 8318 contribute to 14 samples
# clade 8338 contribute to 43 samples
# clade 8366 contribute to 47 samples
# clade 8370 contribute to 20 samples
# clade 8383 contribute to 4 samples
# clade 8386 contribute to 4 samples
# clade 8387 contribute to 2 samples
# clade 8396 contribute to 10 samples
# clade 8474 contribute to 2 samples
# clade 8486 contribute to 9 samples
# clade 8493 contribute to 55 samples
# clade 8506 contribute to 64 samples
# clade 8521 contribute to 4 samples
# clade 8546 contribute to 5 samples
# clade 8599 contribute to 56 samples
# clade 8650 contribute to 61 samples
# clade 8680 contribute to 64 samples
# clade 8761 contribute to 34 samples
# clade 8763 contribute to 21 samples
# clade 8776 contribute to 8 samples
# clade 8798 contribute to 1 samples
# clade 8848 contribute to 32 samples
# clade 8868 contribute to 38 samples
# clade 8952 contribute to 64 samples
# clade 8993 contribute to 3 samples
# clade 9004 contribute to 57 samples
# clade 9013 contribute to 50 samples
# clade 9031 contribute to 7 samples
# clade 9035 contribute to 3 samples
# clade 9054 contribute to 43 samples
# clade 9078 contribute to 33 samples
# clade 9107 contribute to 61 samples
# clade 9167 contribute to 7 samples
# clade 9176 contribute to 43 samples
# clade 9184 contribute to 16 samples
# clade 9197 contribute to 13 samples
# clade 9213 contribute to 21 samples
# clade 9343 contribute to 28 samples
# clade 9356 contribute to 14 samples
# clade 9426 contribute to 8 samples
# clade 9473 contribute to 26 samples
# clade 9553 contribute to 2 samples
# clade 9573 contribute to 3 samples
# clade 9632 contribute to 11 samples
# clade 9701 contribute to 42 samples
# clade 9717 contribute to 20 samples
# clade 9759 contribute to 66 samples
# clade 9779 contribute to 72 samples
# clade 9790 contribute to 21 samples
# clade 9791 contribute to 11 samples
# clade 9794 contribute to 18 samples
# clade 9839 contribute to 5 samples
# clade 9846 contribute to 73 samples
# clade 9855 contribute to 48 samples
# clade 9900 contribute to 51 samples
# clade 9902 contribute to 29 samples
# clade 9979 contribute to 75 samples
# clade 10014 contribute to 32 samples
# clade 10019 contribute to 27 samples
# clade 10087 contribute to 5 samples
# clade 10091 contribute to 162 samples
# clade 10095 contribute to 5 samples
# clade 10101 contribute to 11 samples
# clade 10103 contribute to 10 samples
# clade 10105 contribute to 28 samples
# clade 10128 contribute to 6 samples
# clade 10140 contribute to 8 samples
# clade 10176 contribute to 35 samples
# clade 10236 contribute to 6 samples
# clade 10267 contribute to 10 samples
# clade 10331 contribute to 130 samples
# clade 10410 contribute to 20 samples
# clade 10447 contribute to 11 samples
# clade 10484 contribute to 36 samples
# clade 10515 contribute to 46 samples
# clade 10574 contribute to 18 samples
# clade 10661 contribute to 61 samples
# clade 10709 contribute to 31 samples
# clade 10749 contribute to 19 samples
# clade 10794 contribute to 12 samples
# clade 10813 contribute to 16 samples
# clade 10837 contribute to 25 samples
# clade 10838 contribute to 13 samples
# clade 10840 contribute to 43 samples
# clade 10849 contribute to 22 samples
# clade 10853 contribute to 8 samples
# clade 10863 contribute to 5 samples
# clade 10864 contribute to 19 samples
# clade 10875 contribute to 67 samples
# clade 10893 contribute to 9 samples
# clade 10894 contribute to 3 samples
# clade 10934 contribute to 5 samples
# clade 10942 contribute to 1 samples
# clade 10954 contribute to 10 samples
# clade 10958 contribute to 23 samples
# clade 11009 contribute to 21 samples
# clade 11052 contribute to 19 samples
# clade 11059 contribute to 14 samples
# clade 11106 contribute to 117 samples
# clade 11136 contribute to 13 samples
# clade 11139 contribute to 13 samples
# clade 11203 contribute to 3 samples
# clade 11209 contribute to 14 samples
# clade 11232 contribute to 26 samples
# clade 11244 contribute to 16 samples
# clade 11252 contribute to 18 samples
# clade 11277 contribute to 3 samples
# clade 11304 contribute to 49 samples
# clade 11305 contribute to 36 samples
# clade 11359 contribute to 31 samples
# clade 11390 contribute to 59 samples
# clade 11431 contribute to 79 samples
# clade 11513 contribute to 24 samples
# clade 11543 contribute to 27 samples
# clade 11552 contribute to 13 samples
# clade 11556 contribute to 52 samples
# clade 11594 contribute to 3 samples
# clade 11665 contribute to 5 samples
# clade 11669 contribute to 46 samples
# clade 11716 contribute to 45 samples
# clade 11742 contribute to 12 samples
# clade 11744 contribute to 18 samples
# clade 11745 contribute to 29 samples
# clade 11789 contribute to 26 samples
# clade 11841 contribute to 10 samples
# clade 11858 contribute to 12 samples
# clade 11862 contribute to 3 samples
# clade 11873 contribute to 25 samples
# clade 11932 contribute to 34 samples
# clade 11948 contribute to 26 samples
# clade 11954 contribute to 26 samples
# clade 11962 contribute to 46 samples
# clade 11999 contribute to 9 samples
# clade 12017 contribute to 30 samples
# clade 12026 contribute to 16 samples
# clade 12079 contribute to 159 samples
# clade 12120 contribute to 8 samples
# clade 12170 contribute to 23 samples
# clade 12173 contribute to 37 samples
# clade 12229 contribute to 23 samples
# clade 12312 contribute to 14 samples
# clade 12327 contribute to 77 samples
# clade 12330 contribute to 3 samples
# clade 12387 contribute to 2 samples

# %%
roots = [1272] #1272, 39
s1 = []

ts = tree.at(100)
for s in range(Ne*2, Ne*4):
    if ts.is_descendant(s, roots[0]):
        s1.append(s)
cases = s1
cases
# Out:
# [14146, 14623, 14641, 14983, 17896, 19789, 19958, 20118, 23607, 24489]

# %%
np.random.seed(19)
rest = [x for x in range(Ne*2, Ne*4) if x not in cases]
control = np.random.choice(rest, size=(SampleSize - len(cases)), replace=False)
control
# Out:
# array([15959, 20439, 23864, 23780, 23564, 13906, 23426, 24470, 12683,
#        21548])

# %%
tree_re = tree.recapitate(recombination_rate=0, Ne=Ne, random_seed=1)
com = np.hstack([cases, control])
tree_com = tree_re.simplify(samples=com, keep_unary=True)
tree_com = msprime.mutate(tree_com, rate=MutRate, random_seed=1, keep=True)
geno_com = tree_com.genotype_matrix()
geno_com.shape
# Out:
# (475, 20)

# %%
filename = "infile"
order_com = WriteInput(tree_com, Nrun, SampleSize, Ne, Stop, SeqLen, MutRate, RecRate, filename)
# Out:
# stationary = 0.58137
